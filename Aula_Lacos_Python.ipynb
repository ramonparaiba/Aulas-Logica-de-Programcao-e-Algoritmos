# %% [markdown]
# <a href="https://colab.research.google.com/github/ramonparaiba/Aulas-Logica-de-Programcao-e-Algoritmos/blob/main/Aula_Lacos_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1, 8):
  print(i)

# %%
for i in range (8):
  print(i)

# %%
#Printar todos os números de 10 a 25
#printar todos os números pares de 0 a 50
#Printar todos os números de 10 a 1 (regressivo)
#Mostrar a soma de todos os números de um intervalo, inserido pelo usuário

# %%
for i in range(10, 26):
  print(i)

# %%
for i in range(0, 51, 2):
   print(i)

# %%
for i in range (10, 0, -1):
  print(i)

# %%
#Mostrar a soma de todos os números de um intervalo, inserido pelo usuário
soma = 0
for i in range(5):
  soma = soma + i
print(soma)
# Out:
# 10

# %%
soma = 0
num1 = int(input('insira o primeiro número '))
num2 = int(input('insira o final do intervalo '))

for i in range(num1, num2+1):
  soma=soma+i

print(soma)

# %%
# Pega um range de valores entre 1 e 20.
# e imprime informando se é par ou impar
# ex:  1 é impar

for i in range(1, 21):
  if(i % 2 == 0):
    print(i,'é par')
  else:
    print(i,'é impar')

# %%
#Percorrer lista com FOR
carros = ['chevete', 'fusca', 'variant', 'lada']

for carro in carros:
  print(carro)

# %%
#Laço While - enquanto

# %%
i = 1
while(i <= 5):
  print(i)
  i+=1
#incremento
#soma = soma + 1
#soma +=1

# %%
senha=""
while (senha != "123"):
  senha = input('digite a senha ')
print('Acesso liberado')

# %%
valor = 1

while(valor != 0):
  print(valor,"é diferente de zero")
  valor = int(input('Digite um número, zero sai: '))
print("Digitasse zero, otaro!")

# %%
#Incremente o código anterior para que leia
#os números que o usuário digitou e os some
#quando o usuário digitar 0, sai e exibe o
#somatorio

# %%
valor = 1
soma = 0
while(valor != 0):
  valor = int(input('Digite o valor, zero sai: '))
  soma += valor
print("A soma é", soma)
